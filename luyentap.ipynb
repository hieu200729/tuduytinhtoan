# %%
print('python', 'Java', 'C++', sep = '***', end = '!!')
print('hello 28tech')
# Out:
# python***Java***C++!!hello 28tech

# %%
#đây là chú thích
print('hello 28tech')
# Out:
# hello 28tech

# %%
'''
đây là chú thích
nhiều dòng
'''
print('hello 28tech!')
# Out:
# hello 28tech!

# %%
a = 50
b = 3.43
c = 'hello 28tech'
print(type(a), type(b), type(c), sep = '\n')
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
a = 28.04234387
print('%.2f' % a)              #Cách 1
print('{:.2f}'.format(a))      #Cách 2
print('{:.4f}'.format(a))
# Out:
# 28.04
# 28.04
# 28.0423

# %%
c = 78.044783
d = 2774.374839
print('{:.3f}'.format(c))
print('{:.4f}'.format(d))
print('%.2f' % c)
print('%.3f' % d)
# Out:
# 78.045
# 2774.3748
# 78.04
# 2774.375

# %%
a = True
b = False
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
print(bool(100))
print(bool(0))
print(bool(''))
print(bool('28tech'))
# Out:
# True
# False
# False
# True

# %%
a, b, c = 100, 200, 300
print(a, b, c)
# Out:
# 100 200 300

# %% [markdown]
# Hoán vị vị trí của 2 biến trong python

# %%
a = '28tech'
b = 'python'
a, b = b, a
print(a, b)
# Out:
# python 28tech
